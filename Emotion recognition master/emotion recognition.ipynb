# %%
pip install librosa soundfile numpy sklearn pyaudio
# Out:
# Requirement already satisfied: librosa in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: soundfile in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (0.10.3.post1)
# Requirement already satisfied: numpy in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (1.21.5)
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
# Collecting pyaudio
#   Using cached PyAudio-0.2.12.tar.gz (42 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: resampy>=0.2.2 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (0.4.0)
# Requirement already satisfied: pooch>=1.0 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: audioread>=2.1.9 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: decorator>=4.0.10 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (21.3)
# Requirement already satisfied: numba>=0.45.1 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: scipy>=1.2.0 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: cffi>=1.0 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from soundfile) (1.15.0)
# Requirement already satisfied: pycparser in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: setuptools in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (61.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Building wheels for collected packages: sklearn, pyaudio
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2959 sha256=8a9ebdf3a0c6c7d314f415eabb2b2e6f5003c47ba1437abaa228a63bf5284577
#   Stored in directory: /Users/sandesh/Library/Caches/pip/wheels/f8/e0/3d/9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
#   Building wheel for pyaudio (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/sandesh/opt/anaconda3/bin/python /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py build_wheel /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/tmpiko03eqg
#        cwd: /private/var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/pip-install-hfzircqn/pyaudio_a81007b590194a0d91653baf35f01e1d
#   Complete output (18 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-cpython-39
#   copying src/pyaudio.py -> build/lib.macosx-10.9-x86_64-cpython-39
#   running build_ext
#   building '_portaudio' extension
#   creating build/temp.macosx-10.9-x86_64-cpython-39
#   creating build/temp.macosx-10.9-x86_64-cpython-39/src
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/sandesh/opt/anaconda3/include -arch x86_64 -I/Users/sandesh/opt/anaconda3/include -fPIC -O2 -isystem /Users/sandesh/opt/anaconda3/include -arch x86_64 -DMACOSX=1 -I/usr/local/include -I/usr/include -I/Users/sandesh/opt/anaconda3/include/python3.9 -c src/_portaudiomodule.c -o build/temp.macosx-10.9-x86_64-cpython-39/src/_portaudiomodule.o
#   2022-11-24 17:24:41.645 xcodebuild[2186:96903] Requested but did not find extension point with identifier Xcode.IDEKit.ExtensionSentinelHostApplications for extension Xcode.DebuggerFoundation.AppExtensionHosts.watchOS of plug-in com.apple.dt.IDEWatchSupportCore
#   2022-11-24 17:24:41.646 xcodebuild[2186:96903] Requested but did not find extension point with identifier Xcode.IDEKit.ExtensionPointIdentifierToBundleIdentifier for extension Xcode.DebuggerFoundation.AppExtensionToBundleIdentifierMap.watchOS of plug-in com.apple.dt.IDEWatchSupportCore
#   src/_portaudiomodule.c:31:10: fatal error: 'portaudio.h' file not found
#   #include "portaudio.h"
#            ^~~~~~~~~~~~~
#   1 error generated.
#   error: command '/usr/bin/clang' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pyaudio
# Successfully built sklearn
# Failed to build pyaudio
# ERROR: Could not build wheels for pyaudio which use PEP 517 and cannot be installed directly
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in /Users/sandesh/opt/anaconda3/lib/python3.9/site-packages (0.2.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c numba numba
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sandesh/opt/anaconda3
#
#   added / updated specs:
#     - numba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.9.0               |   py39hecd8cb5_0         884 KB
#     ------------------------------------------------------------
#                                            Total:         884 KB
#
# The following packages will be UPDATED:
#
#   conda              conda-forge::conda-4.14.0-py39h6e9494~ --> pkgs/main::conda-22.9.0-py39hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# conda-22.9.0         | 884 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge librosa
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sandesh/opt/anaconda3
#
#   added / updated specs:
#     - librosa
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.9.0               |   py39h6e9494a_2         962 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         962 KB
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-22.9.0-py39hecd8cb5_0 --> conda-forge::conda-22.9.0-py39h6e9494a_2 None
#
#
#
# Downloading and Extracting Packages
# conda-22.9.0         | 962 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
    if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
    return result

# %%
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
#DataFlair - Emotions to observe
observed_emotions=['calm', 'happy', 'fearful', 'disgust']

# %%
def load_data(test_size=0.2):
    x,y=[],[]
    for file in glob.glob("/Users/sandesh/My_Folder/Python_project/speech-emotion-recognition-ravdess-data/Actor_*/*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
x_train,x_test,y_train,y_test=load_data(test_size=0.25)
# Out:
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 3.0517578e-05  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#  -3.0517578e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#  -3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 3.0517578e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[3.0517578e-05 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 6.1035156e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00039673 -0.00042725
#  -0.00057983] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 3.0517578e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -9.1552734e-05
#  -6.1035156e-05  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -9.1552734e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#  -3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#  -6.1035156e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[6.1035156e-05 9.1552734e-05 6.1035156e-05 ... 3.0517578e-05 6.1035156e-05
#  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  3.0517578e-05  3.0517578e-05 ... -3.0517578e-05
#  -3.0517578e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[1.2207031e-04 9.1552734e-05 9.1552734e-05 ... 1.8310547e-04 1.8310547e-04
#  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-9.1552734e-05 -9.1552734e-05 -1.2207031e-04 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-1.5258789e-04 -9.1552734e-05  6.1035156e-05 ...  9.1552734e-05
#   9.1552734e-05  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 3.0517578e-05 ... 3.0517578e-05 3.0517578e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 9.1552734e-05  6.1035156e-05  6.1035156e-05 ... -8.2702637e-03
#  -8.2397461e-03 -8.1787109e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[3.0517578e-05 3.0517578e-05 6.1035156e-05 ... 3.0517578e-05 0.0000000e+00
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[6.1035156e-05 9.1552734e-05 1.2207031e-04 ... 3.3569336e-04 2.4414062e-04
#  2.7465820e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00 -3.0517578e-05  0.0000000e+00 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[3.0517578e-05 6.1035156e-05 6.1035156e-05 ... 3.0517578e-05 3.0517578e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[3.0517578e-05 3.0517578e-05 3.0517578e-05 ... 6.1035156e-05 6.1035156e-05
#  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 9.1552734e-05 9.1552734e-05
#  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -2.1362305e-04
#   3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 3.0517578e-05  3.0517578e-05  3.0517578e-05 ... -3.0517578e-05
#  -3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-9.1552734e-05 -9.1552734e-05 -6.1035156e-05 ... -3.0517578e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.00018311  0.00018311  0.00018311 ... -0.00015259 -0.00015259
#  -0.00018311] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-1.2207031e-04 -6.1035156e-05 -9.1552734e-05 ... -3.0517578e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00 -3.0517578e-05 -3.0517578e-05 ...  3.0517578e-05
#   2.1362305e-04  1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 9.1552734e-05 6.1035156e-05
#  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-0.00012207 -0.00012207 -0.00012207 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 1.2207031e-04  1.2207031e-04  1.2207031e-04 ... -9.1552734e-05
#  -9.1552734e-05 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.         0.         0.         ... 0.00015259 0.00015259 0.00012207] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  3.0517578e-05  3.0517578e-05 ... -1.8310547e-04
#  -1.2207031e-04 -1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-6.1035156e-05 -6.1035156e-05 -6.1035156e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05 -3.0517578e-05 ... -1.5258789e-04
#  -1.2207031e-04 -1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.00033569 0.00015259 0.00021362 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -2.4414062e-04
#  -1.2207031e-04 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 5.4931641e-04  1.1901855e-03  5.4931641e-04 ...  3.0517578e-05
#  -1.4343262e-03 -8.5449219e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#   3.0517578e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-0.00091553 -0.00115967  0.0012207  ... -0.00064087  0.00033569
#  -0.00048828] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 6.1035156e-05 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-0.00177002 -0.00064087  0.00164795 ...  0.00042725  0.00170898
#   0.00057983] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 3.0517578e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[3.0517578e-05 6.1035156e-05 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[6.1035156e-05 3.0517578e-05 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00057983 -0.00054932
#  -0.00057983] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 6.1035156e-05 9.1552734e-05
#  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[3.0517578e-05 0.0000000e+00 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00 -3.0517578e-05  0.0000000e+00 ...  3.0517578e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 0.0000000e+00
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 1.2207031e-04  9.1552734e-05  9.1552734e-05 ...  0.0000000e+00
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -9.1552734e-05
#  -1.2207031e-04 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-1.2207031e-04 -1.2207031e-04 -1.2207031e-04 ...  9.1552734e-05
#   9.1552734e-05  1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.00036621  0.00045776  0.00048828 ... -0.00021362 -0.00021362
#  -0.00021362] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.00012207 0.00012207 0.00012207 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-0.00082397 -0.00079346 -0.0007019  ... -0.00094604 -0.00061035
#  -0.00076294] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -1.8310547e-04
#  -1.8310547e-04 -1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 3.0517578e-05 9.1552734e-05 ... 1.2207031e-04 1.5258789e-04
#  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 9.1552734e-05  9.1552734e-05  9.1552734e-05 ... -9.1552734e-05
#  -9.1552734e-05 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  2.4414062e-04
#   2.1362305e-04  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-9.1552734e-05 -9.1552734e-05 -6.1035156e-05 ... -6.7138672e-04
#  -7.6293945e-04 -7.3242188e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -9.1552734e-05
#  -9.1552734e-05 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  3.0517578e-05
#   3.0517578e-05  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.         0.         0.         ... 0.00308228 0.00311279 0.00308228] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.00067139  0.00076294  0.00106812 ...  0.00344849 -0.00195312
#  -0.00204468] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -6.1035156e-05 -9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.0000000e+00 -3.0517578e-05  9.1552734e-05 ...  1.0070801e-03
#   1.1901855e-03  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[3.0517578e-05 6.1035156e-05 0.0000000e+00 ... 9.1552734e-05 6.1035156e-05
#  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-6.1035156e-05 -3.0517578e-05 -6.1035156e-05 ... -2.4414062e-04
#  -2.4414062e-04 -2.4414062e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-1.2207031e-04 -1.2207031e-04 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.0000000e+00 3.0517578e-05 0.0000000e+00 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00024414 -0.00024414
#  -0.00021362] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00015259 -0.00015259
#  -0.00012207] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.         0.         0.         ... 0.00018311 0.00024414 0.00024414] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[3.0517578e-05 3.0517578e-05 3.0517578e-05 ... 9.1552734e-05 1.2207031e-04
#  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[0.         0.         0.         ... 0.00018311 0.00015259 0.00018311] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05 -3.0517578e-05 ... -8.5449219e-04
#  -8.5449219e-04 -8.5449219e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05  0.0000000e+00 ...  0.0000000e+00
#   0.0000000e+00  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-9.1552734e-05 -9.1552734e-05 -6.1035156e-05 ...  3.0517578e-05
#   6.1035156e-05  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 2.4414062e-04 -3.0517578e-05 -1.2207031e-04 ...  2.4414062e-04
#   1.2207031e-04  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[-3.0517578e-05 -6.1035156e-05 -6.1035156e-05 ...  0.0000000e+00
#   0.0000000e+00  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 3.0517578e-05  3.0517578e-05  3.0517578e-05 ...  0.0000000e+00
#  -3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[6.1035156e-05 6.1035156e-05 6.1035156e-05 ... 0.0000000e+00 6.1035156e-05
#  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 9.1552734e-05  1.2207031e-04  9.1552734e-05 ... -3.0517578e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# /var/folders/td/8k879ftd3vqg99f58rcggzyr0000gp/T/ipykernel_3873/1649755234.py:15: FutureWarning: Pass y=[ 3.0517578e-05  6.1035156e-05